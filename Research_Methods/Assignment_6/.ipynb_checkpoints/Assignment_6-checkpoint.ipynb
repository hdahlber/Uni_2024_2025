# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats

# %%
# load data
data=pd.read_csv("experiment_results.csv")

# %%
data
# Out:
#    Subject  Time  Defect isolated  Defects detected   Treatment      Program
# 0       S1   145                2                 2     Testing      Counter
# 1       S2   132                1                 1     Testing      Counter
# 2       S3   116                4                 4     Testing  Correlation
# 3       S4   134                0                 0     Testing      Counter
# 4       S5   132                0                 0     Testing      Counter
# 5       S6   150                1                 1     Testing      Counter
# 6       S7   133                0                 0     Testing      Counter
# 7       S8   115                0                 0     Testing  Correlation
# 8       S9   145                1                 1     Testing  Correlation
# 9      S10   132                2                 2     Testing  Correlation
# 10     S11   107                0                 0     Testing  Correlation
# 11     S12   143                2                 2     Testing      Counter
# 12     S13   112                1                 1     Testing  Correlation
# 13     S14   121                0                 0     Testing      Counter
# 14     S15   100                0                 0     Testing  Correlation
# 15     S16   117                0                 0     Testing  Correlation
# 16     S17   105                0                 0     Testing      Counter
# 17     S18   121                2                 2     Testing      Counter
# 18     S19   150                1                 1     Testing  Correlation
# 19     S20   150                0                 1     Testing  Correlation
# 20      S1   105                4                 5  Inspection  Correlation
# 21      S2   107                3                 3  Inspection  Correlation
# 22      S3    95                6                 6  Inspection      Counter
# 23      S4   120                3                 3  Inspection  Correlation
# 24      S5   134                1                 1  Inspection  Correlation
# 25      S6   122                0                 1  Inspection  Correlation
# 26      S7   143                5                 5  Inspection  Correlation
# 27      S8   110                0                 0  Inspection      Counter
# 28      S9   115                2                 2  Inspection      Counter
# 29     S10   110                1                 1  Inspection      Counter
# 30     S11   114                1                 2  Inspection      Counter
# 31     S12   117                4                 4  Inspection  Correlation
# 32     S13   140                0                 0  Inspection      Counter
# 33     S14   150                0                 0  Inspection  Correlation
# 34     S15   105                2                 2  Inspection      Counter
# 35     S16   134                1                 1  Inspection      Counter
# 36     S17   150                2                 2  Inspection  Correlation
# 37     S18   105                4                 4  Inspection  Correlation
# 38     S19   120                4                 4  Inspection      Counter
# 39     S20   125                5                 5  Inspection      Counter

# %% [markdown]
# ### Figure 1. Boxplot of detected defects per program and per technique.

# %%
plt.figure(figsize=(10, 6))
ax = plt.subplot()

# Create a new column combining Program and Treatment
data["Group"] = data["Program"] + " - " + data["Treatment"]

# Boxplot using pandas
data.boxplot(column="Defects detected", by="Group")
plt.title("Boxplot of Detected Defects per Program and per Technique")

plt.xlabel("Program - Technique")
plt.ylabel("Defects Detected")
plt.xticks(rotation=45)


plt.show()

# %% [markdown]
# ### Figure 2. Boxplot of isolated defects per program and per technique.

# %% [markdown]
# ### Table 7. Descriptive statistics for defects detected and isolated, grouped per technique

# %% [markdown]
# ### Table 8. Descriptive statistics for defects detected and isolated grouped per program

# %% [markdown]
# ### Table 9. Results of Wilcoxon signed rank test for the hypotheses regarding effectiveness and efficiency.

# %% [markdown]
# ### Write a short interpretation of the results of the analysis
